# %%
from config import *
import os
from merge import WaveObject
import numpy as np

# %%
from pydub import AudioSegment, effects
from pydub.playback import play

# %%
from sound_merge.augm import *

# %%
# %who
# Out:
# AudioSegment	 concatenate	 mix	 mix_alt	 mix_overlay	 np	 random	 random_segment	 random_silence_mask

# %%
music1 = AudioSegment.from_file(str(test_data / "music1.wav"), format="wav") # 44.1 kHz 16 bit
music2 = AudioSegment.from_file(str(test_data / "music2.wav"), format="wav") # 44.1 kHz 16 bit
speech1 = AudioSegment.from_file(str(test_data / "voice1.wav"), format="wav") # 44.1 kHz 16 bit
speech2 = AudioSegment.from_file(str(test_data / "voice2.wav"), format="wav") # 44.1 kHz 16 bit

# %%
def get_median_dBFS(path):
    """Calculates the median dBFS value of all .wav files in the given directory."""
    dBFS_values = []
    for filename in path.iterdir():
        if filename.suffix != ".wav":
            continue
        audio = AudioSegment.from_file(str(path / filename), format="wav")
        dBFS_values.append(audio.dBFS)
    
    median = sorted(dBFS_values)[len(dBFS_values) // 2]
    return median

# %%
median_test_data = get_median_dBFS(test_data) # -21.55
median_test_data
# Out:
# -19.66155602783681

# %%
for filename in test_data.iterdir():
    if filename.suffix != ".wav":
        continue
    audio = AudioSegment.from_file(str(filename), format="wav")
    print(f"{filename.name}: {audio.dBFS}")
# Out:
# test1.wav: -17.77193040585984
# music2.wav: -23.13888046938965
# music3.wav: -21.553987442786596
# music1.wav: -22.479710462412292
# weird.wav: -4.779303057006685
# voice2.wav: -19.66155602783681
# voice3.wav: -22.913552927255097
# voice1.wav: -18.733923010665663

# %%
def normalize_dBFS(path, target_dBFS, new_path):
    os.makedirs(new_path, exist_ok=True)
    """Normalizes all .wav files in the given directory to the target dBFS value."""
    for filename in path.iterdir():
        if filename.suffix != ".wav":
            continue
        audio = AudioSegment.from_file(str(path / filename), format="wav")
        audio = audio.apply_gain(target_dBFS - audio.dBFS)
        filename = filename.stem + "_normalized.wav"
        audio.export(str(new_path / filename), format="wav")

# %%
normalized_data = home / "sound-merge" / "tests" / "normalized_data"

# %%
normalize_dBFS(test_data, median_test_data, normalized_data)

# %%
print(f"median: {get_median_dBFS(normalized_data)}")
for filename in normalized_data.iterdir():
    if filename.suffix != ".wav":
        continue
    audio = AudioSegment.from_file(str(filename), format="wav")
    print(f"{filename.name}: {audio.dBFS}")
# Out:
# median: -19.66155602783681
# weird_normalized.wav: -19.66155602783681
# music2_normalized.wav: -19.66155602783681
# music3_normalized.wav: -19.66155602783681
# voice1_normalized.wav: -19.66155602783681
# music1_normalized.wav: -19.66155602783681
# voice3_normalized.wav: -19.66920767094335
# test1_normalized.wav: -19.66155602783681
# voice2_normalized.wav: -19.66155602783681

# %%
voice1_normalized = AudioSegment.from_file(str(normalized_data / "voice1_normalized.wav"), format="wav")

# %%
WaveObject.display_waveform_from_audiosegment(speech1)

# %%
WaveObject.display_waveform_from_audiosegment(voice1_normalized)

# %%
audio_ = speech1 + 20
WaveObject.display_waveform_from_audiosegment(audio_)

# %%
audio_.dBFS
# Out:
# -4.779303057006685

# %%
audio_.max_dBFS
# Out:
# 0.0

# %%
audio_.export(test_data / "weird.wav", format="wav")
# Out:
# <_io.BufferedRandom name='/Users/glebmokeev/audio-projects/sound-merge/tests/data/weird.wav'>

# %%
for filename in test_data.iterdir():
    if filename.suffix != ".wav":
        continue
    audio = AudioSegment.from_file(str(filename), format="wav")
    print(f"{filename.name}: {audio.dBFS}")
# Out:
# test1.wav: -17.77193040585984
# music2.wav: -23.13888046938965
# music3.wav: -21.553987442786596
# music1.wav: -22.479710462412292
# weird.wav: -4.779303057006685
# voice2.wav: -19.66155602783681
# voice3.wav: -22.913552927255097
# voice1.wav: -18.733923010665663

# %%
normalize_dBFS(test_data, get_median_dBFS(test_data), normalized_data)

# %%
audio__ = AudioSegment.from_file(str(normalized_data / "weird_normalized.wav"), format="wav")

# %%
WaveObject.display_waveform_from_audiosegment(audio__)

# %%
print(f"median: {get_median_dBFS(normalized_data)}")
for filename in normalized_data.iterdir():
    if filename.suffix != ".wav":
        continue
    audio = AudioSegment.from_file(str(filename), format="wav")
    print(f"{filename.name}: {audio.dBFS}")
# Out:
# median: -19.66155602783681
# weird_normalized.wav: -19.66155602783681
# music2_normalized.wav: -19.66155602783681
# music3_normalized.wav: -19.66155602783681
# voice1_normalized.wav: -19.66155602783681
# music1_normalized.wav: -19.66155602783681
# voice3_normalized.wav: -19.66920767094335
# test1_normalized.wav: -19.66155602783681
# voice2_normalized.wav: -19.66155602783681

# %%
def normalize_headspace(path, new_path, headspace_dBFS):
    os.makedirs(new_path, exist_ok=True)
    """Normalizes all .wav files in the given directory given headspace."""
    for filename in path.iterdir():
        if filename.suffix != ".wav":
            continue
        audio = AudioSegment.from_file(str(path / filename), format="wav")
        audio = audio.normalize(headspace_dBFS)
        filename = filename.stem + "_normalized.wav"
        audio.export(str(new_path / filename), format="wav")

# %%
normalize_headspace(test_data, tests_path / "normalzied_headspace_data", 0.1)

# %%
_audio = AudioSegment.from_file(str(tests_path / "normalzied_headspace_data" / "voice1_normalized.wav"), format="wav")

# %%
WaveObject.display_waveform_from_audiosegment(_audio)

# %%
head_norm_data = tests_path / "normalzied_headspace_data"

# %%
print(f"median: {get_median_dBFS(head_norm_data)}")
for filename in head_norm_data.iterdir():
    if filename.suffix != ".wav":
        continue
    audio = AudioSegment.from_file(str(filename), format="wav")
    print(f"{filename.name}: {audio.dBFS}")
# Out:
# median: -18.328813902727486
# weird_normalized.wav: -4.879601526879456
# music2_normalized.wav: -19.07028343291873
# music3_normalized.wav: -21.652818598530992
# voice1_normalized.wav: -17.918784282424383
# music1_normalized.wav: -18.328813902727486
# voice3_normalized.wav: -23.014227598086382
# test1_normalized.wav: -15.416881190909582
# voice2_normalized.wav: -18.84460215690592

# %%
import random

# %%
def random_silence_mask(audio_segment, total_silence_duration):
    total_silence_duration = min(total_silence_duration, len(audio_segment))

    silence_interval_duration = 1000 
    num_intervals = total_silence_duration // silence_interval_duration

    start_points = sorted(random.sample(range(0, len(audio_segment) - silence_interval_duration), num_intervals))
    modified_audio = audio_segment[:]

    for start in start_points:
        silence_segment = AudioSegment.silent(duration=silence_interval_duration)

        modified_audio = modified_audio[:start] + silence_segment + modified_audio[start + silence_interval_duration:]

    return modified_audio

# %%
au = random_silence_mask(speech1, 5000)

# %%
WaveObject.display_waveform_from_audiosegment(speech1)

# %%
WaveObject.display_waveform_from_audiosegment(au)

# %%
test1 = AudioSegment.from_file(str(test_data / "test1.wav"), format="wav")

# %%
def concatenate(audio_segment1, audio_segment2, crossfade_duration=0):
    return audio_segment1.append(audio_segment2, crossfade=crossfade_duration)

# %%
au = concatenate(test1, speech1, 1000)

# %%
WaveObject.display_waveform_from_audiosegment(test1)

# %%
WaveObject.display_waveform_from_audiosegment(speech1)

# %%
print(np.asarray(speech1.get_array_of_samples()))
# Out:
# [   0    0    0 ...   15 9892   15]

# %%
WaveObject.display_waveform_from_audiosegment(mixed)

# %%
mixed = speech1.overlay(speech1, position=0)
print(f"test1 dBFS: {test1.dBFS}\n speech1 dBFS: {speech1.dBFS}\n mixed dBFS: {mixed.dBFS}")
mixed = mixed.overlay(mixed, position=0)
print(f"test1 dBFS: {test1.dBFS}\n speech1 dBFS: {speech1.dBFS}\n mixed dBFS: {mixed.dBFS}")
# Out:
# test1 dBFS: -19.66155602783681
#  speech1 dBFS: -19.66155602783681
#  mixed dBFS: -13.728071962130704
# test1 dBFS: -19.66155602783681
#  speech1 dBFS: -19.66155602783681
#  mixed dBFS: -8.848569611999578

# %%
def calculate_db_loss(percent):
    return -10 * np.log10(percent)

# %%
def mix(sc1, sc2, audio_segment1, audio_segment2):
    enh1 = audio_segment1 - calculate_db_loss(sc1)
    enh2 = audio_segment2 - calculate_db_loss(sc2)

    mixed_segment = enh1.overlay(enh2, position=0, loop=False)
    print(f"test1 dBFS: {enh1.dBFS}\n speech1 dBFS: {enh2.dBFS}\n mixed dBFS: {mixed_segment.dBFS}")
    return mixed_segment

# %%
mixed = mix(0.1, 0.9, test1, speech1)
# Out:
# test1 dBFS: -29.664684633234724
#  speech1 dBFS: -20.11957165714339
#  mixed dBFS: -20.00477261263832

# %%
normalize_dBFS(test_data, median_test_data, normalized_data)

# %%
speech1 = AudioSegment.from_file(str(normalized_data / "voice1_normalized.wav"), format="wav")
test1 = AudioSegment.from_file(str(normalized_data / "test1_normalized.wav"), format="wav")
print(f"test1 dBFS: {test1.dBFS}\n speech1 dBFS: {speech1.dBFS}")
# Out:
# test1 dBFS: -19.66155602783681
#  speech1 dBFS: -19.66155602783681

# %%
WaveObject.display_waveform_from_audiosegment(speech1 - calculate_db_loss(0.1))

# %%
mixed_1 = mix(test1, speech1)

# %%
WaveObject.display_waveform_from_audiosegment(mixed)

# %%
play(mixed)
# Out:
# Input #0, wav, from '/var/folders/14/gktzbf5x5_18n56bjls0y7cw0000gn/T/tmpdfrzoqg7.wav':
#   Duration: 00:00:10.01, bitrate: 1024 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, 2 channels, s16, 1024 kb/s
#    1.15 M-A:  0.000 fd=   0 aq=  128KB vq=    0KB sq=    0B f=0/0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[139], line 1
# ----> 1 play(mixed)
#
# File ~/audio-projects/sound-merge/.venv/lib/python3.11/site-packages/pydub/playback.py:71, in play(audio_segment)
#      68 else:
#      69     return
# ---> 71 _play_with_ffplay(audio_segment)
#
# File ~/audio-projects/sound-merge/.venv/lib/python3.11/site-packages/pydub/playback.py:16, in _play_with_ffplay(seg)
#      14 with NamedTemporaryFile("w+b", suffix=".wav") as f:
#      15     seg.export(f.name, "wav")
# ---> 16     subprocess.call([PLAYER, "-nodisp", "-autoexit", "-hide_banner", f.name])
#
# File /opt/anaconda3/lib/python3.11/subprocess.py:391, in call(timeout, *popenargs, **kwargs)
#     389 with Popen(*popenargs, **kwargs) as p:
#     390     try:
# --> 391         return p.wait(timeout=timeout)
#     392     except:  # Including KeyboardInterrupt, wait handled that.
#     393         p.kill()
#
# File /opt/anaconda3/lib/python3.11/subprocess.py:1264, in Popen.wait(self, timeout)
#    1262     endtime = _time() + timeout
#    1263 try:
# -> 1264     return self._wait(timeout=timeout)
#    1265 except KeyboardInterrupt:
#    1266     # https://bugs.python.org/issue25942
#    1267     # The first keyboard interrupt waits briefly for the child to
#    1268     # exit under the common assumption that it also received the ^C
#    1269     # generated SIGINT and will exit rapidly.
#    1270     if timeout is not None:
#
# File /opt/anaconda3/lib/python3.11/subprocess.py:2046, in Popen._wait(self, timeout)
#    2044 if self.returncode is not None:
#    2045     break  # Another thread waited.
# -> 2046 (pid, sts) = self._try_wait(0)
#    2047 # Check the pid and loop as waitpid has been known to
#    2048 # return 0 even without WNOHANG in odd situations.
#    2049 # http://bugs.python.org/issue14396.
#    2050 if pid == self.pid:
#
# File /opt/anaconda3/lib/python3.11/subprocess.py:2004, in Popen._try_wait(self, wait_flags)
#    2002 """All callers to this function MUST hold self._waitpid_lock."""
#    2003 try:
# -> 2004     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2005 except ChildProcessError:
#    2006     # This happens if SIGCLD is set to be ignored or waiting
#    2007     # for child processes has otherwise been disabled for our
#    2008     # process.  This child is dead, we can't get the status.
#    2009     pid = self.pid
#
# KeyboardInterrupt:

# %%
def mix(audio_segment1, audio_segment2):
    samples1 = np.array(audio_segment1.get_array_of_samples(), dtype=np.float32) / audio_segment1.max_possible_amplitude
    samples2 = np.array(audio_segment2.get_array_of_samples(), dtype=np.float32) / audio_segment2.max_possible_amplitude

    if len(samples1) < len(samples2):
        samples2 = samples2[:len(samples1)]
    else:
        samples2 = np.pad(samples2, (0, len(samples1) - len(samples2)), 'constant')

    mixed_samples = samples1 + samples2

    peak = np.abs(mixed_samples).max()
    if peak > 1:
        mixed_samples /= peak

    mixed_samples *= audio_segment1.max_possible_amplitude
    
    mixed_audio_segment = AudioSegment(
        data=mixed_samples.astype(np.int16).tobytes(),
        sample_width=audio_segment1.sample_width,
        frame_rate=audio_segment1.frame_rate,
        channels=audio_segment1.channels
    )

    return mixed_audio_segment

# %%
mixed_segment = mix(speech1, test1)
WaveObject.display_waveform_from_audiosegment(mixed_segment)
play(mixed_segment)
# Out:
# Input #0, wav, from '/var/folders/14/gktzbf5x5_18n56bjls0y7cw0000gn/T/tmpl2fbr193.wav':
#   Duration: 00:00:23.44, bitrate: 384 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, 1 channels, s16, 384 kb/s
#   23.26 M-A:  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
#   23.34 M-A:  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0

# %%
mixed_overlay_segment = speech1.overlay(test1, position=0)
WaveObject.display_waveform_from_audiosegment(mixed_overlay_segment)
play(mixed_overlay_segment)
# Out:
# Input #0, wav, from '/var/folders/14/gktzbf5x5_18n56bjls0y7cw0000gn/T/tmpo_phwp5x.wav':
#   Duration: 00:00:23.44, bitrate: 1024 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, 2 channels, s16, 1024 kb/s
#   23.37 M-A: -0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0

# %%
mixed_alt_segment = mix_alt(speech1, test1)
WaveObject.display_waveform_from_audiosegment(mixed_alt_segment)
play(mixed_alt_segment)
# Out:
# Input #0, wav, from '/var/folders/14/gktzbf5x5_18n56bjls0y7cw0000gn/T/tmpqxcxiu2y.wav':
#   Duration: 00:00:23.44, bitrate: 384 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, 1 channels, s16, 384 kb/s
#    7.77 M-A:  0.000 fd=   0 aq=  104KB vq=    0KB sq=    0B f=0/0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[159], line 3
#       1 mixed_alt_segment = mix_alt(speech1, test1)
#       2 WaveObject.display_waveform_from_audiosegment(mixed_alt_segment)
# ----> 3 play(mixed_alt_segment)
#
# File ~/audio-projects/sound-merge/.venv/lib/python3.11/site-packages/pydub/playback.py:71, in play(audio_segment)
#      68 else:
#      69     return
# ---> 71 _play_with_ffplay(audio_segment)
#
# File ~/audio-projects/sound-merge/.venv/lib/python3.11/site-packages/pydub/playback.py:16, in _play_with_ffplay(seg)
#      14 with NamedTemporaryFile("w+b", suffix=".wav") as f:
#      15     seg.export(f.name, "wav")
# ---> 16     subprocess.call([PLAYER, "-nodisp", "-autoexit", "-hide_banner", f.name])
#
# File /opt/anaconda3/lib/python3.11/subprocess.py:391, in call(timeout, *popenargs, **kwargs)
#     389 with Popen(*popenargs, **kwargs) as p:
#     390     try:
# --> 391         return p.wait(timeout=timeout)
#     392     except:  # Including KeyboardInterrupt, wait handled that.
#     393         p.kill()
#
# File /opt/anaconda3/lib/python3.11/subprocess.py:1264, in Popen.wait(self, timeout)
#    1262     endtime = _time() + timeout
#    1263 try:
# -> 1264     return self._wait(timeout=timeout)
#    1265 except KeyboardInterrupt:
#    1266     # https://bugs.python.org/issue25942
#    1267     # The first keyboard interrupt waits briefly for the child to
#    1268     # exit under the common assumption that it also received the ^C
#    1269     # generated SIGINT and will exit rapidly.
#    1270     if timeout is not None:
#
# File /opt/anaconda3/lib/python3.11/subprocess.py:2046, in Popen._wait(self, timeout)
#    2044 if self.returncode is not None:
#    2045     break  # Another thread waited.
# -> 2046 (pid, sts) = self._try_wait(0)
#    2047 # Check the pid and loop as waitpid has been known to
#    2048 # return 0 even without WNOHANG in odd situations.
#    2049 # http://bugs.python.org/issue14396.
#    2050 if pid == self.pid:
#
# File /opt/anaconda3/lib/python3.11/subprocess.py:2004, in Popen._try_wait(self, wait_flags)
#    2002 """All callers to this function MUST hold self._waitpid_lock."""
#    2003 try:
# -> 2004     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2005 except ChildProcessError:
#    2006     # This happens if SIGCLD is set to be ignored or waiting
#    2007     # for child processes has otherwise been disabled for our
#    2008     # process.  This child is dead, we can't get the status.
#    2009     pid = self.pid
#
# KeyboardInterrupt:

# %%
def mix_alt(audiosegment1, audiosegment2):
    samples1 = np.array(audiosegment1.get_array_of_samples())
    samples2 = np.array(audiosegment2.get_array_of_samples())
    
    if len(samples1) < len(samples2):
        samples2 = samples2[:len(samples1)]
    else:
        samples2 = np.pad(samples2, (0, len(samples1) - len(samples2)), 'constant')
        
    mixed_array = np.zeros(len(samples1))

    for i in range(len(samples1)):
        if abs(samples1[i]) > abs(samples2[i]):
            mixed_array[i] = samples1[i]
        else:
            mixed_array[i] = samples2[i]

    mixed_audiosegment = AudioSegment(
        data=mixed_array.astype(np.int16).tobytes(),
        sample_width=audiosegment1.sample_width,
        frame_rate=audiosegment1.frame_rate,
        channels=audiosegment1.channels
    )

    return mixed_audiosegment

# %%
def mix_alt(audiosegment1, audiosegment2):
    samples1 = np.array(audiosegment1.get_array_of_samples())
    samples2 = np.array(audiosegment2.get_array_of_samples())
    
    if len(samples1) < len(samples2):
        samples2 = samples2[:len(samples1)]

    mixed_array = np.zeros(len(samples1))

    for i in range(len(samples1)):
        if abs(samples1[i]) > abs(samples2[i]):
            mixed_array[i] = samples1[i]
        else:
            mixed_array[i] = samples2[i]

    mixed_audiosegment = AudioSegment(
        data=mixed_array.astype(np.int16).tobytes(),
        sample_width=audiosegment1.sample_width,
        frame_rate=audiosegment1.frame_rate,
        channels=audiosegment1.channels
    )

    return mixed_audiosegment

# %%
mixed = mix_alt(speech1, test1)

# %%
WaveObject.display_waveform_from_audiosegment(mixed)

# %%
play(mixed)
# Out:
# Input #0, wav, from '/var/folders/14/gktzbf5x5_18n56bjls0y7cw0000gn/T/tmpivi8wop3.wav':
#   Duration: 00:00:23.44, bitrate: 384 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, 1 channels, s16, 384 kb/s
#   23.33 M-A: -0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B f=0/0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[163], line 1
# ----> 1 play(mixed)
#
# File ~/audio-projects/sound-merge/.venv/lib/python3.11/site-packages/pydub/playback.py:71, in play(audio_segment)
#      68 else:
#      69     return
# ---> 71 _play_with_ffplay(audio_segment)
#
# File ~/audio-projects/sound-merge/.venv/lib/python3.11/site-packages/pydub/playback.py:16, in _play_with_ffplay(seg)
#      14 with NamedTemporaryFile("w+b", suffix=".wav") as f:
#      15     seg.export(f.name, "wav")
# ---> 16     subprocess.call([PLAYER, "-nodisp", "-autoexit", "-hide_banner", f.name])
#
# File /opt/anaconda3/lib/python3.11/subprocess.py:391, in call(timeout, *popenargs, **kwargs)
#     389 with Popen(*popenargs, **kwargs) as p:
#     390     try:
# --> 391         return p.wait(timeout=timeout)
#     392     except:  # Including KeyboardInterrupt, wait handled that.
#     393         p.kill()
#
# File /opt/anaconda3/lib/python3.11/subprocess.py:1264, in Popen.wait(self, timeout)
#    1262     endtime = _time() + timeout
#    1263 try:
# -> 1264     return self._wait(timeout=timeout)
#    1265 except KeyboardInterrupt:
#    1266     # https://bugs.python.org/issue25942
#    1267     # The first keyboard interrupt waits briefly for the child to
#    1268     # exit under the common assumption that it also received the ^C
#    1269     # generated SIGINT and will exit rapidly.
#    1270     if timeout is not None:
#
# File /opt/anaconda3/lib/python3.11/subprocess.py:2046, in Popen._wait(self, timeout)
#    2044 if self.returncode is not None:
#    2045     break  # Another thread waited.
# -> 2046 (pid, sts) = self._try_wait(0)
#    2047 # Check the pid and loop as waitpid has been known to
#    2048 # return 0 even without WNOHANG in odd situations.
#    2049 # http://bugs.python.org/issue14396.
#    2050 if pid == self.pid:
#
# File /opt/anaconda3/lib/python3.11/subprocess.py:2004, in Popen._try_wait(self, wait_flags)
#    2002 """All callers to this function MUST hold self._waitpid_lock."""
#    2003 try:
# -> 2004     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2005 except ChildProcessError:
#    2006     # This happens if SIGCLD is set to be ignored or waiting
#    2007     # for child processes has otherwise been disabled for our
#    2008     # process.  This child is dead, we can't get the status.
#    2009     pid = self.pid
#
# KeyboardInterrupt:

# %%
kls = type(speech1.get_array_of_samples()

# %%
type(speech1)
# Out:
# pydub.audio_segment.AudioSegment

# %%
speech1.max_possible_amplitude
# Out:
# 32768.0

# %%
pydub.audio_segment.AudioSegment()
# Out:
# pydub.audio_segment.AudioSegment

# %%
np.random.randint(-32767, 32767, 16000*10)
# Out:
# array([ 21462, -15160,  31197, ..., -11604,  14466,   4835])

# %%
mixed_audio_segment = AudioSegment(
        data=np.random.randint(-32767, 32767, 16000*10).astype(np.int16).tobytes(),
        sample_width=2,
        frame_rate=16000,
        channels=1
    )

# %%
WaveObject.display_waveform_from_audiosegment(mixed_audio_segment)

# %%
mixed_audio_segment
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
def random_silence_mask(audio_segment, total_silence_duration, silence_interval_duration=1000, fade_duration=200):
    total_silence_duration = min(total_silence_duration, len(audio_segment))
    num_intervals = total_silence_duration // silence_interval_duration

    start_points = sorted(random.sample(range(0, len(audio_segment) - silence_interval_duration), num_intervals))
    modified_audio = audio_segment[:]

    for start in start_points:
        end = start + silence_interval_duration
        start_audio = modified_audio[:start].fade_out(min(fade_duration, start))

        end_audio = modified_audio[end:].fade_in(min(fade_duration, len(modified_audio) - end))

        modified_audio = start_audio + AudioSegment.silent(duration=silence_interval_duration) + end_audio
        
    return modified_audio

# %%
masked_audio = random_silence_mask(mixed_audio_segment, 3000, fade_duration=1000)

# %%
WaveObject.display_waveform_from_audiosegment(masked_audio)
